# %% [markdown]
# # Wine_Prediction_with_LR_Using_LDA

# %% [markdown]
# **Note:**
# - In this experiment, we will perform several operations on a CSV file using the NumPy, Pandas, Matplotlib, Seaborn, and SKLearn libraries.
# - We are going to perform the LDA technique on the Dataset.
# - Our primary focus will be on key operations commonly used in these libraries for building Logistic Regression models.
# - The following operations will be conducted on the CSV file:
#
#    - Importing the necessary libraries.
#    - Loading the dataset for the experiment.
#    - Understanding the data contained in the file.
#    - Performing data cleaning and visualisation operations.
#    - Preparing the data for further processing within the Data Science Life Cycle.
#    - Conducting Exploratory Data Analysis (EDA) on the processed data.
#    - Building predictive models using the EDA-processed data.
#    - Performing model evaluations.
#
# **Experiment Link** -->https://colab.research.google.com/drive/1fFFmwGjr4ZvuUSeYH1KHBHasMk4kMgsd?usp=sharing

# %% [markdown]
# ### STEP 1. Problem statement:-

# %% [markdown]
# ### STEP 2.Importing the necessary libraries.

# %%
# Importing the required libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### STEP 3.Loading the Dataset into the Environment.

# %%
from sklearn.datasets import load_wine

# %%
# Loading the dataset.
dataset = load_wine()

# %%
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)

# %%
# Understanding the dataset.
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
df['Target'] = dataset.target

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  Target
# ...

# %%
df['Target'].unique()
# Out:
# array([0, 1, 2])

# %%
df.shape
# Out:
# (178, 14)

# %% [markdown]
# ### STEP 4. Data Cleaning Operation performed on the dataset.

# %%
# checking for null values.
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# Checking for Duplicate Values.
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### STEP 5. Divide the dataset into features (x) and the target variable (y) for training the model.

# %%
x = df.drop('Target',axis=1)
y = df['Target']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=3)

# %%
x_train.shape
# Out:
# (142, 13)

# %%
y_train.shape
# Out:
# (142,)

# %% [markdown]
# ### STEP 6.Feature Engineering
# - For Encoding, Scaling, and feature creation.

# %% [markdown]
# **LDA -** Linear DiscriminantAnalysis
#
# - It is a supervised machine learning technique.
# - Its main goal is to maximise class separability.
# - LDA works by finding a linear combination of features that best separates the classes.
#
# **Process** -
# - Apply standardisation on the x dataframe.
# - selecting the n components for creating the LDA.
#
#
# - To find the number of components required for LDA, use the formula.
# - n_components = min(no.of features,no.of classes-1).
# - EX:-
#
#     - number of features = 14
#     - number of classes = 03
#     - min(14,3-1) => min(14,2)
#     - 9 is the minimum, so we will select 9 components.

# %%
# STEP 1- Standardize the data
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# - We do not use fit on x_test because we don't want  do not use fit on x_test because we don't to recalculate the mean and sd.

# %%
x_train.std()
# Out:
# np.float64(1.0)

# %%
x_test.std()
# Out:
# np.float64(0.9802407679618195)

# %%
pd.DataFrame(x_train)
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.083561 -0.463937  0.886065 -1.313536  0.103089  1.595769  1.554614
# 1   -0.788315 -1.090776 -1.573102  0.029400 -1.507862 -0.281852  0.013221
# 2    0.711666 -0.664177  0.041874 -0.116571  0.453296  0.953425  1.189027
# 3    0.438942  0.119372  0.005170  0.146177 -0.737407 -1.451248 -1.468888
# 4    1.480250 -0.577116  0.372209 -1.255148  0.873544  1.628710  1.386642
# ..        ...       ...       ...       ...       ...       ...       ...
# 137 -0.094109  1.198928  1.106289 -0.262543  0.173130  0.212259  0.418330
# 138  1.517440 -0.620647  0.298801 -1.138371  1.924164  0.854603  1.060578
# 139 -0.156092  0.493734  0.188689  0.146177  0.313213 -1.615951 -0.757476
# 140  0.129029 -0.455231  1.473329  1.751862  1.153709 -0.133619 -0.698192
# 141 -0.937073 -0.603235 -0.839022 -0.145766 -1.367779 -1.039489  0.042863
#
#            7         8         9         10        11        12
# ...

# %%
 # Apply LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
LDA = LinearDiscriminantAnalysis(n_components=2)
x_train = LDA.fit_transform(x_train,y_train)
x_test = LDA.transform(x_test)

# %%
x_train.shape
# Out:
# (142, 2)

# %%
x_test.shape
# Out:
# (36, 2)

# %% [markdown]
# ### STEP 7.Model Selection & Training: Choose algorithms based on problem type.

# %%
# Train the model.
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# Predicting the values with test data.
model_pred = model.predict(x_test)

# %%
new_df = pd.DataFrame({'Actual':y_test,'Predicted':model_pred})
new_df.head()
# Out:
#      Actual  Predicted
# 40        0          0
# 53        0          0
# 34        0          0
# 109       1          1
# 159       2          2

# %% [markdown]
# ### STEP 8: Model Evaluation
# - Assessing the performance of the model based on various parameters.

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(y_test,model_pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test,model_pred)
# Out:
# array([[15,  0,  0],
#        [ 0, 14,  0],
#        [ 0,  0,  7]])

# %% [markdown]
# - After building the ML model using the PCA data, we evaluated it and achieved " 100 % accuracy ".
